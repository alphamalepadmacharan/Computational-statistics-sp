# %% [markdown]
# <a href="https://colab.research.google.com/github/alphamalepadmacharan/Computational-statistics-sp/blob/main/Copy_of_currency_detection_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt

# %%
train_data_dir =r"C:\Users\padma\OneDrive\Documents\archive"
validation_data_dir = r'C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1'
test_data_dir = r'C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1'

# %%
# Step 1: Convert images to grayscale in all directories
def convert_images_to_grayscale(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            with Image.open(file_path) as img:
                gray_img = img.convert('L').resize(image_size)
                gray_img.save(file_path)
    print(f"All images in {directory} converted to grayscale.")

# %%
import os
from PIL import Image

# Function to convert images to grayscale
def convert_images_to_grayscale(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            # Check if the file is an image (optional step)
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                try:
                    # Open the image
                    with Image.open(file_path) as img:
                        # Convert the image to grayscale
                        grayscale_img = img.convert("L")
                        # Save the grayscale image back
                        grayscale_img.save(file_path)
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")

# Example usage
train_data_dir = 'path_to_train_data'
validation_data_dir = 'path_to_validation_data'
test_data_dir = 'path_to_test_data'

# Convert images in each directory
convert_images_to_grayscale(train_data_dir)
convert_images_to_grayscale(validation_data_dir)
convert_images_to_grayscale(test_data_dir)

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Specify your train data directory
train_data_dir = r"C:\Users\padma\OneDrive\Documents\archive"

# Check if the directory exists
if not os.path.exists(train_data_dir):
    print(f"Directory not found: {train_data_dir}")
else:
    print(f"Directory found: {train_data_dir}")

    # Initialize ImageDataGenerator with augmentation
    train_datagen = ImageDataGenerator(
            rescale=1./255,
            shear_range=0.2,
            rotation_range=30,
            horizontal_flip=True)

    # Use flow_from_directory to load the images
    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(64, 64),  # Resizing images to 64x64
        batch_size=32,
        shuffle=True,
        seed=42,
        color_mode="grayscale",
        class_mode='categorical'
    )

    # Check the classes that were found in the directory
    print("Classes found:", train_generator.class_indices)


# Specify your test data directory
test_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test"

# Check if the directory exists
if not os.path.exists(test_data_dir):
    print(f"Directory not found: {test_data_dir}")
else:
    print(f"Directory found: {test_data_dir}")

    # Initialize ImageDataGenerator for testing
    test_datagen = ImageDataGenerator(rescale=1./255)

    # Use flow_from_directory to load the test images
    test_generator = test_datagen.flow_from_directory(
        test_data_dir,
        target_size=(64, 64),  # Resizing images to 64x64
        batch_size=32,
        shuffle=True,
        seed=42,
        color_mode="grayscale",
        class_mode='categorical'
    )

    # Check the classes found in the directory
    print("Classes found:", test_generator.class_indices)
# Out:
# Directory not found: C:\Users\padma\OneDrive\Documents\archive
# Directory not found: C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2

model = Sequential([
    Conv2D(128, (3, 3), activation='relu', input_shape=(64, 64, 1)),
    MaxPooling2D(2, 2),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    BatchNormalization(),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Dropout to reduce overfitting
    Dense(8, activation='softmax')  # 8 classes
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 62, 62, 128)         │           1,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 31, 31, 128)         │               0 │
# ...

# %%
import os

# Verify the train_data_dir exists
train_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training"

if not os.path.exists(train_data_dir):
    print(f"Error: The directory {train_data_dir} does not exist.")
else:
    print(f"Directory exists: {train_data_dir}")


# Initialize ImageDataGenerator for testing
test_datagen = ImageDataGenerator(rescale=1./255)

import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define paths to the training and test data directories
train_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training"
test_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test"

# Check if the training directory exists
if not os.path.exists(train_data_dir):
    print(f"Error: The directory {train_data_dir} does not exist.")
else:
    print(f"Training directory exists: {train_data_dir}")
    # Initialize ImageDataGenerator for training
    train_datagen = ImageDataGenerator(
            rescale=1./255,
            shear_range=0.2,
            rotation_range=30,
            horizontal_flip=True)

    # Create the training data generator
    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(64, 64),  # Resizing images to 64x64
        batch_size=32,
        shuffle=True,
        seed=42,
        color_mode="grayscale",
        class_mode='categorical'
    )

# Check if the test directory exists
if not os.path.exists(test_data_dir):
    print(f"Error: The directory {test_data_dir} does not exist.")
else:
    print(f"Test directory exists: {test_data_dir}")
    # Initialize ImageDataGenerator for testing
    test_datagen = ImageDataGenerator(rescale=1./255)

    # Create the testing data generator
    test_generator = test_datagen.flow_from_directory(
        test_data_dir,
        target_size=(64, 64),  # Resizing images to 64x64
        batch_size=32,
        shuffle=True,
        seed=42,
        color_mode="grayscale",
        class_mode='categorical'
    )

import os

train_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training"
test_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test"

# Check if the directories exist
if not os.path.exists(train_data_dir):
    print(f"Error: The directory {train_data_dir} does not exist.")
else:
    print(f"Training directory exists: {train_data_dir}")

if not os.path.exists(test_data_dir):
    print(f"Error: The directory {test_data_dir} does not exist.")
else:
    print(f"Test directory exists: {test_data_dir}")
# Out:
# Error: The directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training does not exist.
# Error: The directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training does not exist.
# Error: The directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test does not exist.
# Error: The directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training does not exist.
# Error: The directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test does not exist.

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define paths to the training and test data directories
train_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training"
test_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test"

# Check if the training and test directories exist
if not os.path.exists(train_data_dir):
    print(f"Error: The training directory {train_data_dir} does not exist.")
else:
    print(f"Training directory exists: {train_data_dir}")

    # Initialize ImageDataGenerator for training
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        rotation_range=30,
        horizontal_flip=True)

    # Create the training data generator
    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(64, 64),  # Resizing images to 64x64
        batch_size=32,
        shuffle=True,
        seed=42,
        color_mode="grayscale",
        class_mode='categorical'
    )

# Check if the test directory exists
if not os.path.exists(test_data_dir):
    print(f"Error: The test directory {test_data_dir} does not exist.")
else:
    print(f"Test directory exists: {test_data_dir}")

    # Initialize ImageDataGenerator for testing
    test_datagen = ImageDataGenerator(rescale=1./255)

    # Create the testing data generator
    test_generator = test_datagen.flow_from_directory(
        test_data_dir,
        target_size=(64, 64),  # Resizing images to 64x64
        batch_size=32,
        shuffle=True,
        seed=42,
        color_mode="grayscale",
        class_mode='categorical'
    )

# Check if both generators are created successfully before training the model
if 'train_generator' in locals() and 'test_generator' in locals():
    # Assuming 'model' is defined and compiled before this point
    # Now fit the model using the generators
    epochs = 30
    history = model.fit(
        x=train_generator,          # Training data
        validation_data=test_generator,  # Validation data
        batch_size=32,              # Batch size for training
        verbose=1,                  # Display training progress
        epochs=epochs               # Number of epochs
    )

    # Evaluate the model on the test set
    test_loss, test_accuracy = model.evaluate(test_generator)
    print(f"Test Accuracy: {test_accuracy:.2f}")
    print(f"Test Loss: {test_loss:.2f}")
else:
    print("Error: Could not create the generators. Please check the directory paths.")
# Out:
# Error: The training directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training does not exist.
# Error: The test directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test does not exist.
# Error: Could not create the generators. Please check the directory paths.

# %%
# Save the final model in the recommended Keras format (.keras)
model.save('model_final1.keras')
print("Model saved as 'model_final1.keras'")
# Out:
# Model saved as 'model_final1.keras'

# %%
from tensorflow.keras.models import load_model
import os

# Check the current working directory
print("Current directory:", os.getcwd())

# Path to the model
model_path = 'model_final1.keras'

# Check if the model exists before loading
if os.path.exists(model_path):
    # Load the trained model without the optimizer state
    model = load_model(model_path, compile=False)
    print("Model loaded successfully!")

    # Compile the model again with the desired optimizer
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    print("Model compiled successfully!")
else:
    print(f"Error: {model_path} does not exist. Please check the path.")
# Out:
# Current directory: /content
# Model loaded successfully!
# Model compiled successfully!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Define paths to the training and test data directories
train_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training"
test_data_dir = r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\test"

# Check if the training directory exists
if not os.path.exists(train_data_dir):
    print(f"Error: The training directory {train_data_dir} does not exist.")
else:
    print(f"Training directory exists: {train_data_dir}")

    # Initialize ImageDataGenerator for training
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        rotation_range=30,
        horizontal_flip=True)

    # Create the training data generator
    train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(64, 64),  # Resizing images to 64x64
        batch_size=32,
        shuffle=True,
        seed=42,
        color_mode="grayscale",
        class_mode='categorical'
    )

    # Create a mapping from class index to class name
    class_indices = train_generator.class_indices
    index_to_class = {v: k for k, v in class_indices.items()}
    print("Class index to class name mapping:", index_to_class)
# Out:
# Error: The training directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training does not exist.

# %%
import matplotlib.pyplot as plt
import os

# Define the path to the training dataset
train_data_dir =r"C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training"

# Check if the directory exists
if not os.path.exists(train_data_dir):
    print(f"Error: The directory {train_data_dir} does not exist.")
else:
    print(f"Directory found: {train_data_dir}")

    # Initialize a dictionary to hold class counts
    class_counts = {}

    # Loop through subdirectories (each representing a class)
    for class_dir in os.listdir(train_data_dir):
        class_path = os.path.join(train_data_dir, class_dir)

        # Check if the directory is indeed a directory (not a file)
        if os.path.isdir(class_path):
            class_counts[class_dir] = len(os.listdir(class_path))

    # Plot the distribution of classes
    plt.bar(class_counts.keys(), class_counts.values())
    plt.xlabel('Classes')
    plt.ylabel('Number of Samples')
    plt.title('Class Distribution in Training Dataset')
    plt.xticks(rotation=90)  # Rotate class labels if necessary
    plt.show()
# Out:
# Error: The directory C:\Users\padma\OneDrive\Documents\archive\Indian currency dataset v1\training does not exist.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from google.colab import files

# Upload the model file
uploaded = files.upload()

# After uploading, load the model
model = load_model('model_final1.keras')  # Assuming the file name is 'model_final.h5'

# Function to plot training history
def plot_training_history(history):
    # Plot accuracy
    plt.figure(figsize=(12, 4))

    # Training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Assuming you have a history object from the training, you can plot it:
# plot_training_history(history)
# Out:
#      <input type="file" id="files-cca6cf88-0101-4638-8afc-fafe7268e22f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cca6cf88-0101-4638-8afc-fafe7268e22f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from google.colab import files

# Upload the model file if not already uploaded
from google.colab import files
uploaded = files.upload()

# Load the model
model = load_model('model_final1.keras')  # Make sure the model file is in the current directory

# Function to plot training history
def plot_training_history(history):
    # Plot accuracy
    plt.figure(figsize=(12, 4))

    # Training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
#      <input type="file" id="files-64b6ae47-0123-4791-b9ca-493950f40195" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64b6ae47-0123-4791-b9ca-493950f40195">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Set the path to your test data directory (update this to your actual path)
test_data_dir = '/path/to/your/test/data'  # Update with the actual test data folder

# Create the ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)  # Rescale images

# Create the test generator
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(64, 64),  # Resize images to match the model's input size
    batch_size=32,
    shuffle=False,  # Keep the order of data consistent for true labels and predictions
    class_mode='categorical'  # Use categorical for multi-class classification
)

# Check if the test generator is created successfully
print("Test data generator created successfully!")

# Get the true labels from the test generator
y_true = test_generator.classes  # True labels from the test data

# Get predictions from the model
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)  # Get class with highest probability

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()

# Get the class labels from the test generator
class_names = list(test_generator.class_indices.keys())  # Extract class names from the generator

# Plot the confusion matrix
plot_confusion_matrix(y_true, y_pred_classes, class_names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-b166e822ae85> in <cell line: 14>()
#      12
#      13 # Create the test generator
# ---> 14 test_generator = test_datagen.flow_from_directory(
#      15     test_data_dir,
#      16     target_size=(64, 64),  # Resize images to match the model's input size
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
import matplotlib.pyplot as plt

# Example: Assuming you have already created and compiled the model (e.g., 'model')

# Specify the training and validation data generators
train_data_dir = '/path/to/your/train/data'  # Replace with actual path
validation_data_dir = '/path/to/your/validation/data'  # Replace with actual path

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical'
)

# Train the model and capture the history
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator
)

# Plot the training history
def plot_training_history(history):
    # Plot accuracy
    plt.figure(figsize=(12, 4))

    # Training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Call the function to plot the training history
plot_training_history(history)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-14c9447d0be6> in <cell line: 12>()
#      10 validation_datagen = ImageDataGenerator(rescale=1./255)
#      11
# ---> 12 train_generator = train_datagen.flow_from_directory(
#      13     train_data_dir,
#      14     target_size=(64, 64),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
import numpy as np

# Define the directory for the test dataset
test_data_dir = 'path_to_your_test_data_directory'  # Replace with your actual test data path

# Initialize ImageDataGenerator for test data (only rescaling here)
test_datagen = ImageDataGenerator(rescale=1./255)

# Create the test data generator
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(64, 64),  # Resize the images to the expected input size for your model
    batch_size=32,
    shuffle=False,  # Important to keep the order of data the same for true labels and predictions
    class_mode='categorical'  # Assuming a multi-class classification task
)

# Load the trained model
model = load_model('model_final.h5')  # Make sure to provide the correct path to your model file

# Make predictions on the test set
y_true = test_generator.classes  # True labels (class indices)
y_pred = model.predict(test_generator, verbose=1)  # Make predictions
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert predicted probabilities to class indices

# You can now evaluate the model performance using metrics such as accuracy
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred_classes)
print(f"Accuracy: {accuracy * 100:.2f}%")

# Classification report
print("\nClassification Report:")
print(classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys()))

# Confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-d2d6e61c51fd> in <cell line: 12>()
#      10
#      11 # Create the test data generator
# ---> 12 test_generator = test_datagen.flow_from_directory(
#      13     test_data_dir,
#      14     target_size=(64, 64),  # Resize the images to the expected input size for your model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
class_names = ['Background', '500', '50',
               '2000', '200', '20',
               '100', '10']

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Ensure the correct paths for your test data
test_data_dir = '/path/to/your/test/data'  # Replace with the actual path to your test data

# Initialize ImageDataGenerator for test data
test_datagen = ImageDataGenerator(rescale=1./255)

# Create the test generator
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(64, 64),  # Adjust the target size according to your model's input size
    batch_size=32,
    class_mode='categorical',  # Use 'categorical' for multi-class classification
    shuffle=False  # Keep the order for comparison with the predictions
)

# Assuming your model is already loaded (use model = load_model('your_model_path'))

# Step 1: Get the true labels from the test_generator
y_true = test_generator.classes  # True labels from the test data

# Step 2: Get predictions from the model
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)  # Get the class with the highest probability

# Step 3: Define the function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')
    plt.show()

# Step 4: Get the class labels from the test_generator
class_names = list(test_generator.class_indices.keys())  # Extract class names from the generator

# Step 5: Plot the confusion matrix
plot_confusion_matrix(y_true, y_pred_classes, class_names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-1890520f1a9d> in <cell line: 14>()
#      12
#      13 # Create the test generator
# ---> 14 test_generator = test_datagen.flow_from_directory(
#      15     test_data_dir,
#      16     target_size=(64, 64),  # Adjust the target size according to your model's input size
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...
